# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import ast

tr_df = pd.read_csv("translated_output_turkish2 (3).csv")
raw_en_df = pd.read_pickle("test_data_generated.pkl")
test_set_quality_results = pd.read_json("test_data_control_results.json", lines=True)

# Parse 'reference_contexts' column in tr_df
tr_df['reference_contexts'] = tr_df['reference_contexts'].apply(ast.literal_eval)

# Extract 'Correctness' and 'Details' from the 'Answer' column in test_set_quality_results
test_set_quality_results[['Correctness', 'Details']] = test_set_quality_results['Answer'].str.extract(r'\((\w+),\s*(.*)\)')

# Filter rows with 'Correctness' == "Correct" and get corresponding indices
correct_indices = test_set_quality_results.loc[test_set_quality_results['Correctness'] == "Correct", 'Index_of_df']

# Filter raw_en_df based on correct indices and reset its index
filtered_en_df = raw_en_df.loc[correct_indices.to_list()].reset_index(drop=True)

# Add relevant columns to both dataframes
tr_df["filename"] = filtered_en_df["filename"]
tr_df["synthesizer_name"] = filtered_en_df["synthesizer_name"]
tr_df["language"] = "Turkish"
filtered_en_df["language"] = "English"

# Combine the Turkish and English datasets
final_test_set = pd.concat([filtered_en_df, tr_df], ignore_index=True)

# %%
final_test_set['group'] = final_test_set['language'] + "_" + final_test_set['filename']
stratified_sample, _ = train_test_split(
    final_test_set,
    test_size=(len(final_test_set) - 134),
    stratify=final_test_set['group'],
    random_state=42
)
final_test_set = stratified_sample.drop(columns=['group']).reset_index(drop=True)

# %%
final_test_set.filename = final_test_set.filename.apply(lambda x: x.split(".xlsx")[0])
final_test_set = final_test_set.rename(columns={"filename":"topics"})

# %%
final_test_set
# Out:
#            topics                                         user_input  \
# 0     sports_club                ODTÜ HAT nedir ve ne zaman kuruldu?
# 1     sports_club  ODTÜ kulübü ve faaliyetleri hakkında daha fazl...
# 2    accomadation  YKS Kayıt Programı kullanarak yurt başvurusu n...
# 3         courses  What are the key architectural developments an...
# 4     sports_club  As the Underwater Research Coordinator, I am i...
# ..            ...                                                ...
# 129  student_club   KONTEMPORARY DANS GRUBU için kulüp odası nerede?
# 130           faq  Yurt Bilgi Teknolojileri Destek Koordinatörü o...
# 131       courses  MİMARLIK BÖLÜMÜ'nün tasarım kavramlarının tanı...
# 132           faq  As the Dormitory IT Support Coordinator, I oft...
# 133  student_club  MODERN DİLLER BÖLÜMÜ'NÜN BİLİM KURGU VE FANTAS...
#
#                                     reference_contexts  \
# 0    [Sports Club Name: ODTÜ HAVACILIK TOPLULUĞU YA...
# 1    [Sports Club Name: ODTÜ DENİZCİLİK VE YELKEN T...
# 2    [Application for Dormitories: Students whose f...
# 3    [abea63f4-85ac-4646-ab2c-b2cbc87fdff2\n\nCours...
# 4    [303063e1-3f56-4b2a-aa0d-41b194cbde90\n\nSport...
# ..                                                 ...
# 129  [Student Club Name: CONTEMPORARY DANCE GROUP\n...
# 130  [FAQ Question: How can I reach to department c...
# 131  [Course: ARCH201\nDepartment: This course belo...
# 132  [04024953-33e8-45d8-8493-af6f27671cbb\n\nFAQ Q...
# 133  [Student Club Name: SCIENCE FICTION AND FANTAS...
#
#                                              reference  \
# 0    ODTÜ HAT nedir?  \nODTÜ HAT, ODTÜ Havacılık To...
# 1    Spor Kulübü Adı: ODTÜ DENİZCİLİK VE YELKEN TOP...
# 2    Ankara dışında ailesi yaşayan öğrenciler yurtl...
# 3    The ARCH112 course provides a concise survey o...
# 4    The ODTÜ Aikido Topluluğu, through its Childre...
# ..                                                 ...
# 129  GÜNCEL DANS GRUBU için kulüp odası 9. Yurt, Ze...
# 130  Departman koordinatörünüze ulaşmak için, aşağı...
# 131  MİMARLIK BÖLÜMÜ, tasarım kavramları ile binala...
# 132  The METU VPN Service is essential for students...
# 133  Modern Diller Bölümü, edebi bir tür ve kültüre...
#
#                          synthesizer_name language
# 0    single_hop_specifc_query_synthesizer  Turkish
# 1    single_hop_specifc_query_synthesizer  Turkish
# 2    single_hop_specifc_query_synthesizer  Turkish
# 3    single_hop_specifc_query_synthesizer  English
# 4    single_hop_specifc_query_synthesizer  English
# ..                                    ...      ...
# 129  single_hop_specifc_query_synthesizer  Turkish
# 130  multi_hop_specific_query_synthesizer  Turkish
# 131  single_hop_specifc_query_synthesizer  Turkish
# 132  multi_hop_specific_query_synthesizer  English
# 133  single_hop_specifc_query_synthesizer  Turkish
#
# [134 rows x 6 columns]

# %%
final_test_set = final_test_set.drop(index=120).reset_index(drop=True) #Found Turkish language that supposed to be English

# %%
final_test_set.to_pickle("final_test_data_set.pkl")
